# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_1920

# %%
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2020"
website_url = requests.get(url).text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Bollywood films of 2020 - Wikipedia
#   </title>
#   <script>
# ...

# %%
My_table = soup.find("table",{"class":"wikitable"})

# %%
links = My_table.findAll('a')

# %%
My_table
# Out:
# <table class="wikitable sortable" style="margin:auto; margin:auto;">
# <caption>Highest worldwide gross of 2020
# </caption>
# <tbody><tr>
# <th>Rank</th>
# <th>Title
# </th>
# <th>Production Company</th>
# <th>Distributor
# </th>
# <th>Worldwide Gross</th>
# <th>Ref.
# </th></tr>
# <tr>
# <th style="text-align:center;">1
# </th>
# <td><i><a href="/wiki/Tanhaji" title="Tanhaji">Tanhaji</a></i>
# </td>
# <td><div class="plainlist"><ul><li><a href="/wiki/Ajay_Devgn_FFilms" title="Ajay Devgn FFilms">Ajay Devgn FFilms</a></li><li><a href="/wiki/T-Series_(company)" title="T-Series (company)">T-Series</a></li></ul></div>
# </td>
# <td><a href="/wiki/AA_Films" title="AA Films">AA Films</a>
# </td>
# <td><span class="nowrap"><span style="white-space: nowrap">₹</span>367.65 crore</span> (US$52 million)
# </td>
# <td><sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup><sup class="reference" id="cite_ref-boxoffww_2-0"><a href="#cite_note-boxoffww-2">[2]</a></sup>
# ...

# %%
pip install wikimarkup
# Out:
# Looking in indexes: https://pypi.org/simple, https://data:****@pypi.revolutlabs.com/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikimarkup
import pandas as pd
from pyquery import PyQuery

def get_tables(wiki):
    html = PyQuery(wikimarkup.parse(wiki))
    frames = []
    for table in html('table'):
        data = [[x.text.strip() for x in row]
                for row in table.getchildren()]
        df = pd.DataFrame(data[1:], columns=data[0])
        frames.append(df)
    return frames
# Out:
# Traceback (most recent call last):
#
#   File "/Users/ashish.jha/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-8-90bf0f7028f2>", line 1, in <module>
#     import wikimarkup
#
#   File "/Users/ashish.jha/opt/anaconda3/lib/python3.7/site-packages/wikimarkup/__init__.py", line 28
#     _attributePat = re.compile(ur'''(?:^|\s)([A-Za-z0-9]+)(?:\s*=\s*(?:"([^<"]*)"|'([^<']*)'|([a-zA-Z0-9!#$%&()*,\-./:;<>?@[\]^_`{|}~]+)|#([0-9a-fA-F]+)))''', re.UNICODE)
#                                                                                                                                                             ^
# SyntaxError: invalid syntax

# %%
get_tables("https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_1920")

# %%
url = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2020"

# %%
import pandas as pd
pd.read_html(url, attrs={"class": "wikitable"})[0]
# Out:
#    Opening  Opening.1                               Title  \
# 0      JAN          1                       Ghost Stories
# 1      JAN          3                      Bhangra Paa Le
# 2      JAN          3                   Sab Kushal Mangal
# 3      JAN          3                       Shimla Mirchi
# 4      JAN         10                            Chhapaak
# 5      JAN         10                             Tanhaji
# 6      JAN         17                              Bunker
# 7      JAN         17                        Jai Mummy Di
# 8      JAN         24                               Panga
# 9      JAN         24                    Street Dancer 3D
# 10     JAN         31                           Gul Makai
# 11     JAN         31                Happy Hardy and Heer
# 12     JAN         31                    Jawaani Jaaneman
# 13     JAN         31                          Pagleaazam
# 14     FEB          4                  Operation Parindey
# ...
